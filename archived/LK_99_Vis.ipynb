# 	-0.0000000000000000  0.0000000000000000  0.2917658511111268
# Out:
# Writing Pb9CuP6O25.vasp

# %%
from ase.io import read, write

# %%
Pb9CuP6O25 = read('Pb9CuP6O25.vasp', format='vasp')

# %%
Pb9CuP6O25
# Out:
# Atoms(symbols='Pb9CuP6O25', pbc=True, cell=[[9.930682382105156, -1.4818366361e-06, 0.0], [-4.96533990779532, 8.60022396073567, -0.0], [0.0, 0.0, 7.4109945172796605]])

# %%
from ase.visualize import view

# %%
view(Pb9CuP6O25, viewer='ngl')

# %%
v_Pb9CuP6O25 = view(Pb9CuP6O25, viewer='ngl')

# %%
v_Pb9CuP6O25.view.get_state()
# Out:
# {'_camera_orientation': [],
#  '_camera_str': 'orthographic',
#  '_dom_classes': (),
#  '_gui_theme': None,
#  '_ibtn_fullscreen': 'IPY_MODEL_44de7280f1164e18bd30bc5159bf08b8',
#  '_igui': None,
#  '_iplayer': 'IPY_MODEL_2f506bc77e704761b0945907f2f51e9f',
#  '_model_module': 'nglview-js-widgets',
#  '_model_module_version': '3.0.6',
#  '_model_name': 'NGLModel',
#  '_ngl_color_dict': {},
#  '_ngl_coordinate_resource': {},
#  '_ngl_full_stage_parameters': {},
#  '_ngl_msg_archive': [{'target': 'Stage',
#    'type': 'call_method',
#    'methodName': 'loadFile',
#    'reconstruc_color_scheme': False,
#    'args': [{'type': 'blob',
# ...

# %%
v_Pb9CuP6O25.view.clear_representations()
v_Pb9CuP6O25.view.add_spacefill(selection='all', radius_scale=1, color='element')
v_Pb9CuP6O25.view.center()

# %%
v_Pb9CuP6O25

# %%
# !git clone https://github.com/Frost-group/LeadCopperApatite.git
# Out:
# Cloning into 'LeadCopperApatite'...
# remote: Enumerating objects: 175, done.
# remote: Counting objects: 100% (175/175), done.
# remote: Compressing objects: 100% (129/129), done.
# remote: Total 175 (delta 67), reused 148 (delta 40), pack-reused 0
# Receiving objects: 100% (175/175), 37.19 KiB | 7.44 MiB/s, done.
# Resolving deltas: 100% (67/67), done.
# Filtering content: 100% (41/41), 1.21 GiB | 54.99 MiB/s, done.

# %%
# !pip install pymatgen matgl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 38.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.0/183.0 kB 17.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.4/561.4 kB 45.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 14.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 515.3/515.3 kB 47.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.4/98.4 kB 12.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 34.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 722.8/722.8 kB 53.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.7/154.7 kB 19.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.6/485.6 kB 40.8 MB/s eta 0:00:00
# ...

# %%
# %cd LeadCopperApatite/0003-M3GNET-MD-ZORAC
# Out:
# /content/LeadCopperApatite/0003-M3GNET-MD-ZORAC

# %%
# !ls
# Out:
# 2x2x2_supercell			       P6Pb9Cu1O26H2.vasp
# convert_ase_traj_to_xdatcar.py	       P6Pb9Cu1O26H2.vasp_md.traj.netcdf
# md_ase_m3gnet.py		       P6Pb9Cu1O26H2.vasp_md.traj.pdb
# P3Pb5O13-hydride.vasp		       P6Pb9Cu1O26H2.vasp_md.traj.poscar
# P3Pb5O13-hydride.vasp_md.traj.netcdf   P6Pb9Cu1O26H2.vasp_md.traj.xdatcar
# P3Pb5O13-hydride.vasp_md.traj.pdb      P6Pb9Cu1O26.vasp
# P3Pb5O13-hydride.vasp_md.traj.poscar   P6Pb9Cu1O26.vasp_md.log
# P3Pb5O13-hydride.vasp_md.traj.xdatcar  P6Pb9Cu1O26.vasp_md.traj
# P3Pb5O13.vasp			       P6Pb9Cu1O26.vasp_md.traj.netcdf
# P3Pb5O13.vasp_md.traj.netcdf	       P6Pb9Cu1O26.vasp_md.traj.pdb
# P3Pb5O13.vasp_md.traj.pdb	       P6Pb9Cu1O26.vasp_md.traj.poscar
# P3Pb5O13.vasp_md.traj.poscar	       P6Pb9Cu1O26.vasp_md.traj.xdatcar
# P3Pb5O13.vasp_md.traj.xdatcar	       README.md
# P6Pb9Cu1O26H2_relax_m3gnet.cif	       run.sh

# %%
from ase.io.trajectory import Trajectory
traj = Trajectory('P6Pb9Cu1O26.vasp_md.traj')
P6Pb9Cu1O26 = traj[-1]
view(P6Pb9Cu1O26, viewer='ngl')

# %%
v_P6Pb9Cu1O26 = view(P6Pb9Cu1O26, viewer='ngl')
v_P6Pb9Cu1O26.view.clear_representations()
v_P6Pb9Cu1O26.view.add_spacefill(selection='all', radius_scale=1, color='element')
# v_P6Pb9Cu1O26.view.add_hyperball(selection='all')
# v_P6Pb9Cu1O26.view.add_ball_and_stick(selection='all')
# v_P6Pb9Cu1O26.view.add_licorice(selection='all')
v_P6Pb9Cu1O26.view.center()
v_P6Pb9Cu1O26

# %%
v_P6Pb9Cu1O26 = view(P6Pb9Cu1O26, viewer='ngl')
v_P6Pb9Cu1O26.view.clear_representations()
v_P6Pb9Cu1O26.view.add_surface(selection='all', color='element')
v_P6Pb9Cu1O26.view.center()
v_P6Pb9Cu1O26

# %%
import matplotlib.pyplot as plt
from ase.visualize.plot import plot_atoms
fig, ax = plt.subplots()
plot_atoms(P6Pb9Cu1O26, ax, radii=1.0, rotation=('90x,180y,0z'))
# Out:
# <Axes: >

# %%
# !pip install netCDF4
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 15.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 30.4 MB/s eta 0:00:00
# ...

# %%
from ase.io.netcdftrajectory import read_netcdftrajectory

# %%
P6Pb9Cu1O26H2 = read_netcdftrajectory('P6Pb9Cu1O26H2.vasp_md.traj.netcdf')

# %%
P6Pb9Cu1O26H2
# Out:
# Atoms(symbols='P6Pb9O26H2Cu', pbc=True, cell=[[9.8970079422, 0.0, 0.0], [-4.948503971099999, 8.5710602994, 0.0], [0.0, 0.0, 7.3266339302]], masses=..., momenta=...)

# %%
view(P6Pb9Cu1O26H2, viewer='ngl')

# %%
import matplotlib.pyplot as plt
from ase.visualize.plot import plot_atoms
fig, ax = plt.subplots()
plot_atoms(P6Pb9Cu1O26H2, ax, radii=1.0, rotation=('90x,180y,0z'))
# Out:
# <Axes: >

# %%
# %cd 2x2x2_supercell
# Out:
# /content/LeadCopperApatite/0003-M3GNET-MD-ZORAC/2x2x2_supercell

# %%
# !ls
# Out:
# md_ase_m3gnet.py       P6Pb9Cu1O26H2.vasp		  P6Pb9Cu1O26.vasp
# P3Pb5O13-hydride.vasp  P6Pb9Cu1O26H2.vasp_md.traj.netcdf  run.sh
# P3Pb5O13.vasp	       P6Pb9Cu1O26H2.vasp_md.traj.pdb

# %%
P6Pb9Cu1O26H2_2x2x2 = read_netcdftrajectory('P6Pb9Cu1O26H2.vasp_md.traj.netcdf')

# %%
P6Pb9Cu1O26H2_2x2x2
# Out:
# Atoms(symbols='H54Cu27O702P162Pb243', pbc=True, cell=[[29.691023826600002, 0.0, 0.0], [-14.845511913299998, 25.713180898199994, 0.0], [0.0, 0.0, 21.9799017906]], masses=..., momenta=...)

# %%
view(P6Pb9Cu1O26H2_2x2x2, viewer='ngl')

# %%
fig, ax = plt.subplots()
plot_atoms(P6Pb9Cu1O26H2_2x2x2, ax, radii=0.3, rotation=('90x,180y,0z'))
# Out:
# <Axes: >

# %%
v_P6Pb9Cu1O26H2_2x2x2 = view(P6Pb9Cu1O26H2_2x2x2, viewer='ngl')
v_P6Pb9Cu1O26H2_2x2x2.view.clear_representations()
v_P6Pb9Cu1O26H2_2x2x2.view.add_spacefill(selection='all', radius_scale=1, color='element')
v_P6Pb9Cu1O26H2_2x2x2.view.center()
v_P6Pb9Cu1O26H2_2x2x2

# %%
v_P6Pb9Cu1O26H2_2x2x2 = view(P6Pb9Cu1O26H2_2x2x2, viewer='ngl')
v_P6Pb9Cu1O26H2_2x2x2.view.clear_representations()
v_P6Pb9Cu1O26H2_2x2x2.view.add_surface(selection='all', color='element')
v_P6Pb9Cu1O26H2_2x2x2.view.center()
v_P6Pb9Cu1O26H2_2x2x2

# %%
P6Pb9Cu1O26_2x2x2 = read('P6Pb9Cu1O26.vasp', format='vasp')

# %%
P6Pb9Cu1O26_2x2x2
# Out:
# Atoms(symbols='P6Pb9O26Cu', pbc=True, cell=[[9.8970079422, 0.0, 0.0], [-4.9485039711, 8.5710602994, 0.0], [0.0, 0.0, 7.3266339302]])

# %%
view(P6Pb9Cu1O26_2x2x2, viewer='ngl')

# %%
v_P6Pb9Cu1O26_2x2x2 = view(P6Pb9Cu1O26_2x2x2, viewer='ngl')
v_P6Pb9Cu1O26_2x2x2.view.clear_representations()
v_P6Pb9Cu1O26_2x2x2.view.add_spacefill(selection='all', radius_scale=1, color='element')
v_P6Pb9Cu1O26_2x2x2.view.center()
v_P6Pb9Cu1O26_2x2x2

# %%
v_P6Pb9Cu1O26_2x2x2 = view(P6Pb9Cu1O26_2x2x2, viewer='ngl')
v_P6Pb9Cu1O26_2x2x2.view.clear_representations()
v_P6Pb9Cu1O26_2x2x2.view.add_surface(selection='all', color='element')
v_P6Pb9Cu1O26_2x2x2.view.center()
v_P6Pb9Cu1O26_2x2x2

# %%
fig, ax = plt.subplots()
plot_atoms(P6Pb9Cu1O26_2x2x2, ax, radii=0.3, rotation=('90x,45y,0z'))
# Out:
# <Axes: >

# %%
P3Pb5O13_hydride_2x2x2 = read('P3Pb5O13-hydride.vasp', format='vasp')
view(P3Pb5O13_hydride_2x2x2, viewer='ngl')

# %%
lat = P6Pb9Cu1O26.cell.get_bravais_lattice()
print(lat.description())
lat.plot_bz(show=True)
# Out:
# HEX(a=9.89701, c=7.32663)
#   Variant name: HEX
#   Special point names: GMKALH
#   Default path: GMKGALHA,LM,KH
#
#   Special point coordinates:
#     G   0.0000  0.0000  0.0000
#     M   0.5000  0.0000  0.0000
#     K   0.3333  0.3333  0.0000
#     A   0.0000  0.0000  0.5000
#     L   0.5000  0.0000  0.5000
#     H   0.3333  0.3333  0.5000
# <Axes3D: >

# %%
from ase.calculators.test import FreeElectrons

# %%
P6Pb9Cu1O26.calc = FreeElectrons(nvalence=1,
                       kpts={'path': 'GMKGALHA', 'npoints': 200})
P6Pb9Cu1O26.get_potential_energy()
bs = P6Pb9Cu1O26.calc.band_structure()
bs.plot(emin=-10, emax=10)
# Out:
# <Axes: ylabel='energies [eV]'>

# %%
P6Pb9Cu1O26.calc = FreeElectrons(nvalence=1,
                       kpts={'path': 'LM', 'npoints': 200})
P6Pb9Cu1O26.get_potential_energy()
bs = P6Pb9Cu1O26.calc.band_structure()
bs.plot(emin=-10, emax=10)
# Out:
# <Axes: ylabel='energies [eV]'>

# %%
P6Pb9Cu1O26.calc = FreeElectrons(nvalence=1,
                       kpts={'path': 'KH', 'npoints': 200})
P6Pb9Cu1O26.get_potential_energy()
bs = P6Pb9Cu1O26.calc.band_structure()
bs.plot(emin=-10, emax=10)
# Out:
# <Axes: ylabel='energies [eV]'>

# %%
P6Pb9Cu1O26.calc = FreeElectrons(nvalence=1,
                       kpts={'path': 'GA', 'npoints': 200})
P6Pb9Cu1O26.get_potential_energy()
bs = P6Pb9Cu1O26.calc.band_structure()
bs.plot(emin=-10, emax=10)
# Out:
# <Axes: ylabel='energies [eV]'>

# %%
P6Pb9Cu1O26.calc = FreeElectrons(nvalence=1,
                       kpts={'path': 'GK', 'npoints': 200})
P6Pb9Cu1O26.get_potential_energy()
bs = P6Pb9Cu1O26.calc.band_structure()
bs.plot(emin=-10, emax=10)
# Out:
# <Axes: ylabel='energies [eV]'>

# %%
P6Pb9Cu1O26.calc = FreeElectrons(nvalence=1,
                       kpts={'path': 'GM', 'npoints': 200})
P6Pb9Cu1O26.get_potential_energy()
bs = P6Pb9Cu1O26.calc.band_structure()
bs.plot(emin=-10, emax=10)
# Out:
# <Axes: ylabel='energies [eV]'>
